# %%
import json

# %%
def load_data(filename):
    with open(filename,"r") as f:
        data = json.load(f)
    return data

# %%
data = load_data("data2.json")

# %%
data
# Out:
# {'users': [{'id': 1, 'name': 'Amit', 'friends': [2, 3], 'liked_pages': [101]},
#   {'id': 2, 'name': 'Priya', 'friends': [], 'liked_pages': [102]},
#   {'id': 3, 'name': '', 'friends': [1], 'liked_pages': [101, 103]},
#   {'id': 4, 'name': 'Sara', 'friends': [2, 2], 'liked_pages': []}],
#  'pages': [{'id': 101, 'name': 'Python Developers'},
#   {'id': 102, 'name': 'Data Science Enthusiasts'},
#   {'id': 103, 'name': 'AI & ML Community'},
#   {'id': 104, 'name': 'Web Dev Hub'},
#   {'id': 104, 'name': 'BlockChain'}]}

# %%
def clean_data(data):
    
    # Remove users with missing names
    data["users"] = [user for user in data["users"] if user["name"].strip()] 
    
    # removing duplicate friends
    for user in data["users"]:
        user['friends'] = list(set(user['friends']))
    
    # Removing inactive users
    # Any one of both should be present if both are null remove it 
    data["users"] = [user for user in data['users'] if user['friends'] or user['liked_pages']]
    
    # Remove duplicate pages
    unique_pages = {}
    for page in data['pages']:
        # In Dict one id comes one time as a Key that's y we take a key one time only = page below
        unique_pages[page['id']] = page
    data['pages'] = list(unique_pages.values())
    return data

# load the data
data = json.load(open("data2.json"))
data = clean_data(data) 
json.dump(data,open("cleaned_data2.json","w"),indent = 4)
print("Data has been Updated")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-42cd571beb1b> in <module>
#      21
#      22 # load the data
# ---> 23 data = json.load(open("data2.json"))
#      24 data = clean_data(data)
#      25 json.dump(data,open("cleaned_data2.json","w"),indent = 4)
#
# NameError: name 'json' is not defined

# %%
# unique_pages.values()

# %%
import json

def load_data(filename):
    with open(filename,'r') as f:
        data = json.load(f)
        return data

# %%
data = load_data('new.json')

# %%
data

# %%
def clean_data(data):
    data['users'] = [user for user in data['users'] if user['name'].strip()]
    
    for user in data["users"]:
        user['friends'] = list(set(user['friends']))
        
    data['users'] = [user for user in data['users'] if user['friend'] or user['liked_pages']]
    # unique elements
    unique_pages= {}

# %%
import json

def load_data(filename):
    with open(filename,'r') as f:
        data = json.load(f)
    return data

# %%
data = load_data("data.json")

# %%
data

# %%
# data 
# remove
