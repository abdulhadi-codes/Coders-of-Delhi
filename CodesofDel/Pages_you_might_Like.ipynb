# %%
# RECOMENDING THE PAGES

# %%
import json

# %%
def load_data(filename):
    with open(filename,"r") as f:
        data = json.load(f)

    return data

# %%
import json

def load(filename):
    with open(filename,"r") as f:
        return json.load(f)
    
# Function that showes liked pages a user might lik on Common Interest
def find_pages_you_might_like(user_id, data):
    # Dictionary to store User interations with pages
    user_pages = {}
    # Populate the Dictionary Populate means making the user pages a key that isa Dictionary 
    for user in data['users']:
        user_pages = set(user['liked_pages'])
    # If the user is not found 
    if user_id not in user_pages:
        return []
    
    user_liked_pages = user_pages[user_id]
    
    page_suggestion = {}
    # Assume 1 person liked 5 pages and 2nd person (other user / other person) liked 8 pages if there are 4 common pages liked between then there is probabilyty that the rest pages might also be liked by each Ther
    
    
    
    for other_user,pages in user_pages.items():
        # this loop is for assume user_id =  1 to be found but user_id should not be in the same 1 so we use this condition below
        if other_user != user_id: 
            # we use the shared pages for the intersections of Common pages amongst them
            # the  user_liked_pages is a set so we perform the interection operation
            shared_pages = user_liked_pages.intersection(pages)
        for page in pages:
            if page not in user_liked_pages:
                page_suggestions[page] = page_suggestion.get()
    sorted_pages = sorted(page_suggestion.items(),key = lambda x : x[1] , reverse = True)
    return [page_id for page_id, _ in sorted_pages ]
data = load_data("massive_data.json")
user_id = 1
page_recomendations = find_pages_you_might_like(user_id, data)
print(f"Pages You Might Like for User {user_id}: {page_recomendations}")
# Out:
# Pages You Might Like for User 1: []
