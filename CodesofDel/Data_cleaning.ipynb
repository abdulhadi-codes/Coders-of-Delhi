# %%
import json

# %%
# function to load the data
def load_data(filename):
    with open(filename,"r") as f:
        data = json.load(f)

    return data

# %%
data = load_data("data.json")

# %%
data
# Out:
# {'users': [{'id': 1, 'name': 'Amit', 'friends': [2, 3], 'liked_pages': [101]},
#   {'id': 2, 'name': 'Priya', 'friends': [1, 4], 'liked_pages': [102]},
#   {'id': 3, 'name': 'Rahul', 'friends': [1], 'liked_pages': [101, 103]},
#   {'id': 4, 'name': 'Sara', 'friends': [2], 'liked_pages': [104]}],
#  'pages': [{'id': 101, 'name': 'Python Developers'},
#   {'id': 102, 'name': 'Data Science Enthusiasts'},
#   {'id': 103, 'name': 'AI & ML Community'},
#   {'id': 104, 'name': 'Web Dev Hub'}]}

# %%
type(data)
# Out:
# dict

# %% [raw]
# ## M- note
# inside " user['ID']" // inside "DOUBLE QUOTES " wirte ['SINGLE QUOTES MUST ELSE ERROR!!']
#
# print(f" the user ID is {user['id']} & name is {user['name']}")

# %%
# function to use disply users and connections
def display_users(data):
    print("The data collection")
    for user in data['users']:
        print(f"ID { user['id']}. -  {user['name']} and the friends with {user['friends']} and the name of pages are {user['liked_pages']}")
    print("The pages printed are")
    for pages in data['pages']:
        print(f"{pages['id']} : {pages['name']}")

display_users(data)
# Out:
# The data collection
# ID 1. -  Amit and the friends with [2, 3] and the name of pages are [101]
# ID 2. -  Priya and the friends with [1, 4] and the name of pages are [102]
# ID 3. -  Rahul and the friends with [1] and the name of pages are [101, 103]
# ID 4. -  Sara and the friends with [2] and the name of pages are [104]
# The pages printed are
# 101 : Python Developers
# 102 : Data Science Enthusiasts
# 103 : AI & ML Community
# 104 : Web Dev Hub

# %%
import json

def clean_data(data):
    # Remove users with the missing names
    data["users"] = [user for user in data["users"] if user["name"].strip()] # strip() helps in removing values with EMPTY VALUES /EMPTY  SPACES  inside the data name = " " the SPACE !!
    # M-note: dont Do mistake of RETURNING SOON  
    # return data

    # REMOVE DUPLICATE FRIENDS 
    for user in data["users"]:
         # HERE BELOW we converted friends to SET and then converted SET back to LIST bcz set DOESNT HAVE DUPLICATE VALUES
        user["friends"] = list(set(user["friends"])) 
        
    # REMOVE INACTIVE USERS
    #M- note : Close the Brackets Properly else it'll print error
    data["users"] = [user for user in data["users"]
                     # since the user DOesnt make frinds / like pages we delete it from Data Set
                     if user["friends"] or user["liked_pages"] # in this BOTH should'nt be empty Atleast one should be there else TERMINATE THE WHOLE LINE IF BOTH NOT PRESENT
                    ]
    # Remove the duplicate pages
    unique_pages = {}
    for page in data['pages']:
        unique_pages[page['id']] = page
    data['pages'] = list(unique_pages.values())
    
        
    return data
     
# Load the Data
data = json.load(open("data2.json"))
data = clean_data(data)
json.dump(data, open("cleaned_data2.json","w"), indent = 4) # this is a file  not in jupyter but in clean format for LAYMAN Understaing normal FILE TYPE
print("Data has been closed Successfully")
# Out:
# Data has been closed Successfully
